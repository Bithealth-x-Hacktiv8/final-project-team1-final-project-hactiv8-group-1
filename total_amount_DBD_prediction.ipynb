# %% [markdown]
# # Digital Kesehatan
#
# ## Problem
# Data yang akan dianalisa didapatkan dari pasien dimulai dari administrasi, hasil pemeriksaan, monitoring dalam rawat inap maupun rawat jalan, tracking asuransi, estimasi nominal biaya, pembayaran dan pasien kembali pulih. Data tersebut terpusat dalam satu server. Data tersebut dapat divisualisasikan berbagai macam summary sehingga pasien mendapatkan transparansi informasi serta perusahaan mendapatkan insight untuk evaluasi pelayanan.

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# ### Import Library

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

from scipy.stats import skew, chi2_contingency

from sklearn.preprocessing import OneHotEncoder, MinMaxScaler

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Read dataframe

# %%
df = pd.read_csv("csv/hasil_dummy.csv")
df.head()
# Out:
#       id     date_in    date_out branch hospital_care  drug_quantity  \
# 0  30591  2020-01-01  2020-01-03   RSMD    Rawat Inap              4
# 1  46456  2020-01-01  2020-01-05   RSMA    Rawat Inap              1
# 2  99188  2020-01-01  2020-01-01   RSMD   Rawat Jalan              5
# 3  23001  2020-01-01  2020-01-05   RSMA    Rawat Inap              2
# 4  29319  2020-01-01  2020-01-02   RSMS    Rawat Inap              3
#
#    admin_price      cogs   payment             review  ...  \
# 0        50000  13719597  Asuransi             Netral  ...
# 1        50000  14625784   Pribadi  Sangat Tidak Puas  ...
# 2        50000   3859519   Pribadi        Sangat Puas  ...
# 3        50000   6086762  Asuransi             Netral  ...
# 4        50000   3003078  Asuransi  Sangat Tidak Puas  ...
#
#    doctor_visit_price  room_price_total  food_price_total  \
# 0            900000.0            600000          240000.0
# 1           1500000.0           1250000          550000.0
# 2            300000.0                 0               0.0
# 3           1500000.0           1500000          750000.0
# 4            600000.0            600000          300000.0
#
#    surgery_price_total  lab_price_total  infus_price_total total_amount  \
# 0             15000000            90000           495000.0     17535000
# 1             15000000           200000           825000.0     19485000
# 2                    0            90000                0.0       990000
# 3              4000000           150000           825000.0      8925000
# 4                    0           200000           330000.0      2305000
#
#    revenue                  created_at is_DBD
# 0  3815403  2024-05-02 09:28:45.585259  False
# 1  4859216  2024-05-02 09:28:45.585265  False
# 2 -2869519  2024-05-02 09:28:45.585267  False
# 3  2838238  2024-05-02 09:28:45.585268  False
# 4  -698078  2024-05-02 09:28:45.585268  False
#
# [5 rows x 43 columns]

# %%
df.shape
# Out:
# (9474, 43)

# %%
# Filter only for DBD Suspect
df = df[df['is_DBD'] == True]
df.head()
# Out:
#         id     date_in    date_out branch hospital_care  drug_quantity  \
# 9    36434  2020-01-01  2020-01-01   RSMD   Rawat Jalan              3
# 51   37182  2020-01-07  2020-01-07   RSMD   Rawat Jalan              1
# 71   88444  2020-01-11  2020-01-13   RSMS    Rawat Inap              5
# 150  16458  2020-01-21  2020-01-21   RSMS   Rawat Jalan              3
# 161  21894  2020-01-23  2020-01-23   RSMD   Rawat Jalan              3
#
#      admin_price     cogs   payment             review  ...  \
# 9          50000  1090736   Pribadi  Sangat Tidak Puas  ...
# 51         50000  1900825   Pribadi               Puas  ...
# 71         50000  4821621  Asuransi        Sangat Puas  ...
# 150        50000  2171651   Pribadi        Sangat Puas  ...
# 161        50000  4792984   Pribadi               Puas  ...
#
#      doctor_visit_price  room_price_total  food_price_total  \
# 9              300000.0                 0               0.0
# 51             250000.0                 0               0.0
# 71             750000.0            750000          330000.0
# 150            300000.0                 0               0.0
# 161            300000.0                 0               0.0
#
#      surgery_price_total  lab_price_total  infus_price_total total_amount  \
# 9                      0            90000                0.0       590000
# 51                     0           200000                0.0       550000
# 71                     0           200000           495000.0      2825000
# 150                    0           200000                0.0       700000
# 161                    0            90000                0.0       560000
#
#      revenue                  created_at is_DBD
# 9    -500736  2024-05-02 09:28:45.585271   True
# 51  -1350825  2024-05-02 09:28:45.585294   True
# 71  -1996621  2024-05-02 09:28:45.585305   True
# 150 -1471651  2024-05-02 09:28:45.585350   True
# 161 -4232984  2024-05-02 09:28:45.585357   True
#
# [5 rows x 43 columns]

# %%
df.shape
# Out:
# (539, 43)

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
df.sample(5)
# Out:
#          id     date_in    date_out branch hospital_care  drug_quantity  \
# 7066  48395  2022-12-04  2022-12-04   RSMA   Rawat Jalan              4
# 6647  38398  2022-09-27  2022-10-01   RSMS    Rawat Inap              2
# 185   57826  2020-01-26  2020-01-26   RSMS   Rawat Jalan              3
# 1290  38215  2020-06-25  2020-06-27   RSMD    Rawat Inap              1
# 8973  65786  2023-10-13  2023-10-17   RSMD    Rawat Inap              2
#
#       admin_price     cogs  payment             review  ...  \
# 7066        50000  4255264  Pribadi  Sangat Tidak Puas  ...
# 6647        50000  2762757  Pribadi               Puas  ...
# 185         50000  2823223  Pribadi             Netral  ...
# 1290        50000  2179778  Pribadi             Netral  ...
# 8973        50000  2212864  Pribadi        Sangat Puas  ...
#
#       doctor_visit_price  room_price_total  food_price_total  \
# 7066            300000.0                 0               0.0
# 6647           1500000.0            750000          250000.0
# 185             250000.0                 0               0.0
# 1290            750000.0            900000          450000.0
# 8973           1250000.0           1500000          750000.0
#
#       surgery_price_total  lab_price_total  infus_price_total total_amount  \
# 7066                    0           200000                0.0       750000
# 6647                    0           200000           825000.0      3675000
# 185                     0           200000                0.0       620000
# 1290                    0            90000           495000.0      2775000
# 8973                    0           195000           825000.0      4670000
#
#       revenue                  created_at is_DBD
# 7066 -3505264  2024-05-02 09:28:45.588995   True
# 6647   912243  2024-05-02 09:28:45.588776   True
# 185  -2203223  2024-05-02 09:28:45.585369   True
# 1290   595222  2024-05-02 09:28:45.585974   True
# 8973  2457136  2024-05-02 09:28:45.590056   True
#
# [5 rows x 43 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 539 entries, 9 to 9392
# Data columns (total 43 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   539 non-null    int64
#  1   date_in              539 non-null    object
#  2   date_out             539 non-null    object
#  3   branch               539 non-null    object
#  4   hospital_care        539 non-null    object
#  5   drug_quantity        539 non-null    int64
#  6   admin_price          539 non-null    int64
#  7   cogs                 539 non-null    int64
#  8   payment              539 non-null    object
#  9   review               539 non-null    object
#  10  patient_id           539 non-null    int64
#  11  room_id              539 non-null    int64
#  12  drug_id              539 non-null    int64
#  13  doctor_id            539 non-null    int64
#  14  surgery_id           539 non-null    int64
#  15  lab_id               539 non-null    int64
#  16  patient_name         539 non-null    object
#  17  gender               539 non-null    object
#  18  age                  539 non-null    int64
#  19  room_type            298 non-null    object
#  20  food_price           298 non-null    float64
#  21  room_price           298 non-null    float64
#  22  drug_brand           539 non-null    object
#  23  drug_type            539 non-null    object
#  24  drug_price           539 non-null    int64
#  25  doctor               539 non-null    object
#  26  doctor_price         539 non-null    int64
#  27  surgery              0 non-null      object
#  28  surgery_price        0 non-null      float64
#  29  lab                  539 non-null    object
#  30  lab_price            539 non-null    float64
#  31  drug_price_total     539 non-null    int64
#  32  days_diff            539 non-null    float64
#  33  doctor_visit_price   539 non-null    float64
#  34  room_price_total     539 non-null    int64
#  35  food_price_total     539 non-null    float64
#  36  surgery_price_total  539 non-null    int64
#  37  lab_price_total      539 non-null    int64
#  38  infus_price_total    539 non-null    float64
#  39  total_amount         539 non-null    int64
#  40  revenue              539 non-null    int64
#  41  created_at           539 non-null    object
#  42  is_DBD               539 non-null    bool
# dtypes: bool(1), float64(8), int64(19), object(15)
# memory usage: 181.6+ KB

# %%
# Convert date objects to dates
df['date_in'] = pd.to_datetime(df['date_in'])
df['date_out'] = pd.to_datetime(df['date_out'])
df['created_at'] = pd.to_datetime(df['created_at'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 539 entries, 9 to 9392
# Data columns (total 43 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   539 non-null    int64
#  1   date_in              539 non-null    datetime64[ns]
#  2   date_out             539 non-null    datetime64[ns]
#  3   branch               539 non-null    object
#  4   hospital_care        539 non-null    object
#  5   drug_quantity        539 non-null    int64
#  6   admin_price          539 non-null    int64
#  7   cogs                 539 non-null    int64
#  8   payment              539 non-null    object
#  9   review               539 non-null    object
#  10  patient_id           539 non-null    int64
#  11  room_id              539 non-null    int64
#  12  drug_id              539 non-null    int64
#  13  doctor_id            539 non-null    int64
#  14  surgery_id           539 non-null    int64
#  15  lab_id               539 non-null    int64
#  16  patient_name         539 non-null    object
#  17  gender               539 non-null    object
#  18  age                  539 non-null    int64
#  19  room_type            298 non-null    object
#  20  food_price           298 non-null    float64
#  21  room_price           298 non-null    float64
#  22  drug_brand           539 non-null    object
#  23  drug_type            539 non-null    object
#  24  drug_price           539 non-null    int64
#  25  doctor               539 non-null    object
#  26  doctor_price         539 non-null    int64
#  27  surgery              0 non-null      object
#  28  surgery_price        0 non-null      float64
#  29  lab                  539 non-null    object
#  30  lab_price            539 non-null    float64
#  31  drug_price_total     539 non-null    int64
#  32  days_diff            539 non-null    float64
#  33  doctor_visit_price   539 non-null    float64
#  34  room_price_total     539 non-null    int64
#  35  food_price_total     539 non-null    float64
#  36  surgery_price_total  539 non-null    int64
#  37  lab_price_total      539 non-null    int64
#  38  infus_price_total    539 non-null    float64
#  39  total_amount         539 non-null    int64
#  40  revenue              539 non-null    int64
#  41  created_at           539 non-null    datetime64[ns]
#  42  is_DBD               539 non-null    bool
# dtypes: bool(1), datetime64[ns](3), float64(8), int64(19), object(12)
# memory usage: 181.6+ KB

# %%
# Menghitung jumlah NaN atau nilai yang kosong
print("Missing Values")
print(df.isnull().sum())

#Check for missing values Percentage
print("\nMissing Values Percentage")
print(df.isna().sum()/len(df))
# Out:
# Missing Values
# id                       0
# date_in                  0
# date_out                 0
# branch                   0
# hospital_care            0
# drug_quantity            0
# admin_price              0
# cogs                     0
# payment                  0
# review                   0
# patient_id               0
# room_id                  0
# drug_id                  0
# doctor_id                0
# surgery_id               0
# lab_id                   0
# patient_name             0
# gender                   0
# age                      0
# room_type              241
# food_price             241
# room_price             241
# drug_brand               0
# drug_type                0
# drug_price               0
# doctor                   0
# doctor_price             0
# surgery                539
# surgery_price          539
# lab                      0
# lab_price                0
# drug_price_total         0
# days_diff                0
# doctor_visit_price       0
# room_price_total         0
# food_price_total         0
# surgery_price_total      0
# lab_price_total          0
# infus_price_total        0
# total_amount             0
# revenue                  0
# created_at               0
# is_DBD                   0
# dtype: int64
#
# Missing Values Percentage
# id                     0.000000
# date_in                0.000000
# date_out               0.000000
# branch                 0.000000
# hospital_care          0.000000
# drug_quantity          0.000000
# admin_price            0.000000
# cogs                   0.000000
# payment                0.000000
# review                 0.000000
# patient_id             0.000000
# room_id                0.000000
# drug_id                0.000000
# doctor_id              0.000000
# surgery_id             0.000000
# lab_id                 0.000000
# patient_name           0.000000
# gender                 0.000000
# age                    0.000000
# room_type              0.447124
# food_price             0.447124
# room_price             0.447124
# drug_brand             0.000000
# drug_type              0.000000
# drug_price             0.000000
# doctor                 0.000000
# doctor_price           0.000000
# surgery                1.000000
# surgery_price          1.000000
# lab                    0.000000
# lab_price              0.000000
# drug_price_total       0.000000
# days_diff              0.000000
# doctor_visit_price     0.000000
# room_price_total       0.000000
# food_price_total       0.000000
# surgery_price_total    0.000000
# lab_price_total        0.000000
# infus_price_total      0.000000
# total_amount           0.000000
# revenue                0.000000
# created_at             0.000000
# is_DBD                 0.000000
# dtype: float64

# %%
# Fill missing values in categorical columns (forgot to change it in dags)
categorical_cols = ["room_type", "surgery", "lab"]
df[categorical_cols] = df[categorical_cols].fillna("Tidak Digunakan")

# Fill missing values in numerical columns
numerical_cols = ["food_price", "room_price", "surgery_price", "lab_price"]
df[numerical_cols] = df[numerical_cols].fillna(0)

# %%
# Data Duplicate
df.duplicated().sum()
# Out:
# 0

# %%
# Grouping columns by data type
cats = []
nums = []
temps = []

for column, dtype in df.dtypes.items():
    if dtype == 'object' or dtype == 'bool':
        cats.append(column)
    elif dtype == 'int64' or dtype == 'float64':
        nums.append(column)
    elif dtype == 'datetime64[ns]':
        temps.append(column)

# Display the grouped columns
print("Categorical columns:", cats)
print("Numerical columns:", nums)
print("Temporal columns:", temps)
# Out:
# Categorical columns: ['branch', 'hospital_care', 'payment', 'review', 'patient_name', 'gender', 'room_type', 'drug_brand', 'drug_type', 'doctor', 'surgery', 'lab', 'is_DBD']
# Numerical columns: ['id', 'drug_quantity', 'admin_price', 'cogs', 'patient_id', 'room_id', 'drug_id', 'doctor_id', 'surgery_id', 'lab_id', 'age', 'food_price', 'room_price', 'drug_price', 'doctor_price', 'surgery_price', 'lab_price', 'drug_price_total', 'days_diff', 'doctor_visit_price', 'room_price_total', 'food_price_total', 'surgery_price_total', 'lab_price_total', 'infus_price_total', 'total_amount', 'revenue']
# Temporal columns: ['date_in', 'date_out', 'created_at']

# %%
#Statistik Deskriptif kolom numerikal
df[nums].describe()
# Out:
#                  id  drug_quantity  admin_price          cogs   patient_id  \
# count    539.000000     539.000000        539.0  5.390000e+02   539.000000
# mean   54908.519481       2.951763      50000.0  2.993519e+06  5034.756957
# std    26342.041830       1.419949          0.0  1.126522e+06  2691.032265
# min    10189.000000       1.000000      50000.0  1.008802e+06    10.000000
# 25%    31245.000000       2.000000      50000.0  2.024529e+06  2755.000000
# 50%    55322.000000       3.000000      50000.0  3.017703e+06  5237.000000
# 75%    78305.500000       4.000000      50000.0  3.965024e+06  7363.000000
# max    99994.000000       5.000000      50000.0  4.998849e+06  9393.000000
#
#           room_id     drug_id   doctor_id  surgery_id      lab_id  ...  \
# count  539.000000  539.000000  539.000000       539.0  539.000000  ...
# mean     1.417440    6.525046    3.504638         0.0    2.667904  ...
# std      1.523713    3.487741    0.500443         0.0    1.682821  ...
# min      0.000000    1.000000    3.000000         0.0    1.000000  ...
# 25%      0.000000    3.000000    3.000000         0.0    1.000000  ...
# 50%      1.000000    7.000000    4.000000         0.0    2.000000  ...
# 75%      3.000000    9.000000    4.000000         0.0    5.000000  ...
# max      4.000000   12.000000    4.000000         0.0    5.000000  ...
#
#        drug_price_total   days_diff  doctor_visit_price  room_price_total  \
# count        539.000000  539.000000        5.390000e+02      5.390000e+02
# mean      190538.033395    2.233766        7.334879e+05      5.027829e+05
# std       133414.857150    2.248728        5.002751e+05      5.323823e+05
# min        40000.000000    0.000000        2.500000e+05      0.000000e+00
# 25%       100000.000000    0.000000        3.000000e+05      0.000000e+00
# 50%       160000.000000    2.000000        6.000000e+05      4.500000e+05
# 75%       250000.000000    4.000000        1.200000e+06      9.000000e+05
# max       550000.000000    6.000000        1.800000e+06      1.800000e+06
#
#        food_price_total  surgery_price_total  lab_price_total  \
# count        539.000000                539.0       539.000000
# mean      218293.135436                  0.0    163460.111317
# std       247215.082087                  0.0     50164.634019
# min            0.000000                  0.0     90000.000000
# 25%            0.000000                  0.0     90000.000000
# 50%       160000.000000                  0.0    195000.000000
# 75%       400000.000000                  0.0    200000.000000
# max       900000.000000                  0.0    200000.000000
#
#        infus_price_total  total_amount       revenue
# count         539.000000  5.390000e+02  5.390000e+02
# mean       368571.428571  2.227134e+06 -7.663850e+05
# std        371040.058359  1.619082e+06  2.018107e+06
# min             0.000000  4.300000e+05 -4.409955e+06
# 25%             0.000000  6.600000e+05 -2.274538e+06
# 50%        330000.000000  1.990000e+06 -9.958430e+05
# 75%        660000.000000  3.642500e+06  6.415510e+05
# max        990000.000000  5.990000e+06  4.583371e+06
#
# [8 rows x 27 columns]

# %% [markdown]
# **Statistik Deskriptif kolom numerical**
#
# Analisis statistik deskriptif menunjukkan variasi luas dalam biaya dan penggunaan layanan medis untuk pasien DBD. Usia pasien rata-rata sekitar 50 tahun. Jumlah obat rata-rata sekitar 3 unit, dan biaya administrasi selalu 50.000. Biaya barang yang dijual (COGS) rata-rata sekitar 3.000.000. Harga kamar, obat, dan kunjungan dokter rata-rata masing-masing sekitar 125.000, 65.000, dan 733.000. Durasi perawatan baik rawat inap dan rawat jalan rata-rata sekitar 2 hari dengan maksimum 6 hari. Total biaya perawatan rata-rata sekitar 2.200.000. Pendapatan sering negatif, menunjukkan perbedaan antara biaya yang ditagih dan pendapatan yang diterima.

# %%
# Statistik deskriptif kolom kategorikal
df[cats].describe()
# Out:
#        branch hospital_care  payment       review   patient_name     gender  \
# count     539           539      539          539            539        539
# unique      3             2        2            5            539          2
# top      RSMA    Rawat Inap  Pribadi  Sangat Puas  Widya Samosir  Perempuan
# freq      181           298      386          116              1        276
#
#               room_type drug_brand drug_type doctor          surgery  \
# count               539        539       539    539              539
# unique                5          9         3      2                1
# top     Tidak Digunakan   Tramadol      Umum   Umum  Tidak Digunakan
# freq                241         76       193    272              539
#
#              lab is_DBD
# count        539    539
# unique         3      1
# top     Serologi   True
# freq         191    539

# %% [markdown]
# **Statistik Deskriptif kolom categorical**
#
# Pada kolom kategorikal, cabang rumah sakit RSMA paling banyak tercatat (181 entri). Mayoritas pasien menerima rawat inap (298 entri) dan pembayaran pribadi paling umum (386 entri). Ulasan "Sangat Puas" terbanyak (116 entri), dan mayoritas pasien perempuan (276 entri). Tipe kamar paling umum "Tidak Digunakan" (241 entri). Merek obat Tramadol paling sering digunakan (76 entri), dan tipe obat "Umum" paling umum (193 entri). Dokter yang paling banyak menangani pasien adalah "Umum" (272 entri). Pasien tidak menjalani operasi dan layanan lab paling banyak serologi (191 entri). Total data sebanyak 539 menunjukkan keragaman besar dalam biaya dan layanan.

# %%
# Statistik deskriptif kolom temporal
df[temps].describe()
# Out:
#                              date_in                       date_out  \
# count                            539                            539
# mean   2022-01-23 22:39:51.094619648  2022-01-25 15:00:20.037105664
# min              2020-01-01 00:00:00            2020-01-01 00:00:00
# 25%              2021-01-29 00:00:00            2021-01-31 00:00:00
# 50%              2022-02-12 00:00:00            2022-02-15 00:00:00
# 75%              2023-01-23 00:00:00            2023-01-26 00:00:00
# max              2023-12-21 00:00:00            2023-12-25 00:00:00
#
#                           created_at
# count                            539
# mean   2024-05-02 09:28:45.587927040
# min       2024-05-02 09:28:45.585271
# 25%    2024-05-02 09:28:45.586718464
# 50%    2024-05-02 09:28:45.588047104
# 75%    2024-05-02 09:28:45.589150464
# max       2024-05-02 09:28:45.590276

# %% [markdown]
# **Statistik Deskriptif kolom temporal**
#
# Pada kolom temporal, tanggal masuk pasien berkisar dari 1 Januari 2020 hingga 21 Desember 2023, dengan rata-rata 23 Januari 2022. Tanggal keluar berkisar dari 1 Januari 2020 hingga 25 Desember 2023, dengan rata-rata 25 Januari 2022.

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# ### Numerical columns

# %%
# List of numerical columns
num_exclude_cols = ['id', 'patient_id', 'room_id', 'drug_id', 'doctor_id', 'surgery_id', 'lab_id']
num_cols = [col for col in nums if col not in num_exclude_cols]

# Create gridspec layout
grid = gridspec.GridSpec(15, 4)
plt.figure(figsize=(20, 60))

# Loop through each numerical column
for i, column in enumerate(num_cols):
    ax = plt.subplot(grid[i])
    skewness = skew(df[column])
    sns.histplot(data=df, x=column, kde=True, color='skyblue', edgecolor='lightblue', ax=ax)
    ax.set_title(f'{column} Distribution (skewness: {skewness:.2f})')
    ax.set_xlabel(column)
    ax.set_ylabel('Frequency')

# Adjust layout and show the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Categorical columns

# %%
# List of categorical columns
cat_cols = [col for col in cats if col != 'patient_name']

# Create gridspec layout
grid = gridspec.GridSpec(15, 4)
plt.figure(figsize=(20, 80))

# Loop through categorical features and plot bar charts
for i, feature in enumerate(cat_cols):
    ax = plt.subplot(grid[i])
    sns.countplot(data=df, x=feature, ax=ax, order=df[feature].value_counts().index, color='skyblue')
    ax.set_title(f'Countplot of {feature}')
    ax.set_xlabel(feature)
    ax.set_ylabel('Count')
    # Rotate x-axis labels
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
    
    # Calculate percentages and annotate bars
    total = float(len(df[feature]))
    for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height()/total)
        x = p.get_x() + p.get_width() / 2
        y = p.get_height() + 0.02
        ax.annotate(percentage, (x, y), ha='center')

# Adjust layout and show the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# ### Numerical columns

# %%
# Create grid of subplots
grid = gridspec.GridSpec(15, 4)
plt.figure(figsize=(20, 60))

# Plot scatter plots
for n, col in enumerate(num_cols):
    ax = plt.subplot(grid[n])
    sns.scatterplot(x=col, y='total_amount', data=df, ax=ax)
    ax.set_title(f'Scatter Plot of {col} vs Total Amount')
    ax.set_xlabel(col)
    ax.set_ylabel('Total Amount')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Categorical columns

# %%
# Create gridspec layout
grid = gridspec.GridSpec(15, 4)
plt.figure(figsize=(20, 90))

# Plot box plots for each categorical column against 'total_amount'
for i, col in enumerate(cat_cols):
    ax = plt.subplot(grid[i])
    sns.boxplot(x=col, y='total_amount', data=df, ax=ax, color='skyblue')
    ax.set_title(f'Boxplot of {col} vs Total Amount')
    ax.set_xlabel(col)
    ax.set_ylabel('Total Amount')
    # Rotate x-axis labels
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Multivariate Analysis

# %% [markdown]
# ### Numerical columns

# %%
# Subset the DataFrame with only the numerical features
numerical_df = df[num_cols]

# Calculate the correlation matrix
correlation_matrix = numerical_df.corr()

# Plot a heatmap to visualize the correlation matrix
plt.figure(figsize=(20, 20))
sns.heatmap(correlation_matrix, annot=True, cmap='Blues', fmt='.2f', square=True)
plt.title('Correlation Heatmap by Numerical Features')
plt.show()

# %% [markdown]
# ### Categorical columns

# %%
# Create a contingency table for each combination of categorical variable and the target variable
chi_square_results = {}

for column in cat_cols:
    contingency_table = pd.crosstab(df[column], df['total_amount'])
    chi2, p, _, _ = chi2_contingency(contingency_table)
    chi_square_results[column] = {'chi2': chi2, 'p-value': p}

# Display the results
for column, result in chi_square_results.items():
    print(f"Chi-square test for {column} vs {'total_amount'}:")
    print(f"Chi-square value: {result['chi2']}")
    print(f"P-value: {result['p-value']}")
    print('-' * 30)
# Out:
# Chi-square test for branch vs total_amount:
# Chi-square value: 625.6900202681153
# P-value: 0.42857113082389553
# ------------------------------
# Chi-square test for hospital_care vs total_amount:
# Chi-square value: 539.0
# P-value: 1.370688791597761e-14
# ------------------------------
# Chi-square test for payment vs total_amount:
# Chi-square value: 484.88826238612893
# P-value: 7.551989275886488e-10
# ------------------------------
# Chi-square test for review vs total_amount:
# Chi-square value: 1227.299261974218
# P-value: 0.5958090328503773
# ------------------------------
# Chi-square test for gender vs total_amount:
# Chi-square value: 305.4800312876937
# P-value: 0.5618279514226932
# ------------------------------
# Chi-square test for room_type vs total_amount:
# Chi-square value: 1964.5454751873174
# P-value: 1.0064900706369356e-35
# ------------------------------
# Chi-square test for drug_brand vs total_amount:
# Chi-square value: 2702.2632305797615
# P-value: 0.0010501009594942872
# ------------------------------
# Chi-square test for drug_type vs total_amount:
# Chi-square value: 883.8947296230708
# P-value: 1.4267173254579399e-11
# ------------------------------
# Chi-square test for doctor vs total_amount:
# Chi-square value: 421.8997356628357
# P-value: 2.343629570950818e-05
# ------------------------------
# Chi-square test for surgery vs total_amount:
# Chi-square value: 0.0
# P-value: 1.0
# ------------------------------
# Chi-square test for lab vs total_amount:
# Chi-square value: 898.6831279102895
# P-value: 1.4261097911579849e-12
# ------------------------------
# Chi-square test for is_DBD vs total_amount:
# Chi-square value: 0.0
# P-value: 1.0
# ------------------------------

# %% [markdown]
# * Nilai chi-squared yang mendekati nol menunjukkan bahwa tidak ada perbedaan signifikan antara distribusi observed dan expected.
# * Nilai p-value adalah 1, itu biasanya menunjukkan bahwa tidak ada perbedaan yang signifikan antara sampel yang diuji. Hal ini bisa terjadi jika sampel yang diuji memiliki distribusi yang sama persis.

# %%
column_to_drop = ['id', 'patient_id', 'room_id', 'drug_id', 'doctor_id', 'surgery_id', 'lab_id', 'patient_name', 'created_at',
                 'admin_price', 'drug_price_total', 'doctor_visit_price', 'room_price_total', 'food_price_total',
                  'surgery_price_total', 'lab_price_total', 'infus_price_total', 'revenue', 'cogs',
                  'surgery_price', 'surgery', 'is_DBD']

# %% [markdown]
# ## Data Cleansing

# %%
# Menghitung jumlah NaN atau nilai yang kosong
print("Missing Values")
print(df.isnull().sum())

#Check for missing values Percentage
print("\nMissing Values Percentage")
print(df.isna().sum()/len(df))
# Out:
# Missing Values
# id                     0
# date_in                0
# date_out               0
# branch                 0
# hospital_care          0
# drug_quantity          0
# admin_price            0
# cogs                   0
# payment                0
# review                 0
# patient_id             0
# room_id                0
# drug_id                0
# doctor_id              0
# surgery_id             0
# lab_id                 0
# patient_name           0
# gender                 0
# age                    0
# room_type              0
# food_price             0
# room_price             0
# drug_brand             0
# drug_type              0
# drug_price             0
# doctor                 0
# doctor_price           0
# surgery                0
# surgery_price          0
# lab                    0
# lab_price              0
# drug_price_total       0
# days_diff              0
# doctor_visit_price     0
# room_price_total       0
# food_price_total       0
# surgery_price_total    0
# lab_price_total        0
# infus_price_total      0
# total_amount           0
# revenue                0
# created_at             0
# is_DBD                 0
# dtype: int64
#
# Missing Values Percentage
# id                     0.0
# date_in                0.0
# date_out               0.0
# branch                 0.0
# hospital_care          0.0
# drug_quantity          0.0
# admin_price            0.0
# cogs                   0.0
# payment                0.0
# review                 0.0
# patient_id             0.0
# room_id                0.0
# drug_id                0.0
# doctor_id              0.0
# surgery_id             0.0
# lab_id                 0.0
# patient_name           0.0
# gender                 0.0
# age                    0.0
# room_type              0.0
# food_price             0.0
# room_price             0.0
# drug_brand             0.0
# drug_type              0.0
# drug_price             0.0
# doctor                 0.0
# doctor_price           0.0
# surgery                0.0
# surgery_price          0.0
# lab                    0.0
# lab_price              0.0
# drug_price_total       0.0
# days_diff              0.0
# doctor_visit_price     0.0
# room_price_total       0.0
# food_price_total       0.0
# surgery_price_total    0.0
# lab_price_total        0.0
# infus_price_total      0.0
# total_amount           0.0
# revenue                0.0
# created_at             0.0
# is_DBD                 0.0
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 539 entries, 9 to 9392
# Data columns (total 43 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   539 non-null    int64
#  1   date_in              539 non-null    datetime64[ns]
#  2   date_out             539 non-null    datetime64[ns]
#  3   branch               539 non-null    object
#  4   hospital_care        539 non-null    object
#  5   drug_quantity        539 non-null    int64
#  6   admin_price          539 non-null    int64
#  7   cogs                 539 non-null    int64
#  8   payment              539 non-null    object
#  9   review               539 non-null    object
#  10  patient_id           539 non-null    int64
#  11  room_id              539 non-null    int64
#  12  drug_id              539 non-null    int64
#  13  doctor_id            539 non-null    int64
#  14  surgery_id           539 non-null    int64
#  15  lab_id               539 non-null    int64
#  16  patient_name         539 non-null    object
#  17  gender               539 non-null    object
#  18  age                  539 non-null    int64
#  19  room_type            539 non-null    object
#  20  food_price           539 non-null    float64
#  21  room_price           539 non-null    float64
#  22  drug_brand           539 non-null    object
#  23  drug_type            539 non-null    object
#  24  drug_price           539 non-null    int64
#  25  doctor               539 non-null    object
#  26  doctor_price         539 non-null    int64
#  27  surgery              539 non-null    object
#  28  surgery_price        539 non-null    float64
#  29  lab                  539 non-null    object
#  30  lab_price            539 non-null    float64
#  31  drug_price_total     539 non-null    int64
#  32  days_diff            539 non-null    float64
#  33  doctor_visit_price   539 non-null    float64
#  34  room_price_total     539 non-null    int64
#  35  food_price_total     539 non-null    float64
#  36  surgery_price_total  539 non-null    int64
#  37  lab_price_total      539 non-null    int64
#  38  infus_price_total    539 non-null    float64
#  39  total_amount         539 non-null    int64
#  40  revenue              539 non-null    int64
#  41  created_at           539 non-null    datetime64[ns]
#  42  is_DBD               539 non-null    bool
# dtypes: bool(1), datetime64[ns](3), float64(8), int64(19), object(12)
# memory usage: 181.6+ KB

# %% [markdown]
# ## Feature Engineering

# %%
# Define age groups
age_bins = [0, 18, 30, 45, 60, float('inf')]
age_labels = ['0-18', '19-30', '31-45', '46-60', '60+']

# Assign age groups to the data
df['age_group'] = pd.cut(df['age'], bins=age_bins, labels=age_labels, right=False)

# %%
# Plot the pie chart
custom_palette = sns.color_palette('Blues_r', len(df['age_group'].unique()))
plt.figure(figsize=(4, 4))
df['age_group'].value_counts().plot(kind='pie', autopct='%.2f%%', colors=custom_palette)
plt.title('Distribution of Age Groups')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
# Create a box plot
plt.figure(figsize=(10, 6))
sns.boxplot(x='age_group', y='total_amount', data=df, color='skyblue')
plt.title('Total Amount by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Total Amount')
plt.show()

# %%
df_copy = df
df_copy['date_in_year'] = df_copy['date_in'].dt.year
df_copy['date_in_year']
# Out:
# 9       2020
# 51      2020
# 71      2020
# 150     2020
# 161     2020
#         ...
# 9337    2023
# 9342    2023
# 9345    2023
# 9352    2023
# 9392    2023
# Name: date_in_year, Length: 539, dtype: int32

# %%
df_copy['date_in_month'] = df_copy['date_in'].dt.month
df_copy['date_in_month']
# Out:
# 9        1
# 51       1
# 71       1
# 150      1
# 161      1
#         ..
# 9337    12
# 9342    12
# 9345    12
# 9352    12
# 9392    12
# Name: date_in_month, Length: 539, dtype: int32

# %%
df_copy['date_out_year'] = df_copy['date_out'].dt.year
df_copy['date_out_year']
# Out:
# 9       2020
# 51      2020
# 71      2020
# 150     2020
# 161     2020
#         ...
# 9337    2023
# 9342    2023
# 9345    2023
# 9352    2023
# 9392    2023
# Name: date_out_year, Length: 539, dtype: int32

# %%
df_copy['date_out_month'] = df_copy['date_out'].dt.month
df_copy['date_out_month']
# Out:
# 9        1
# 51       1
# 71       1
# 150      1
# 161      1
#         ..
# 9337    12
# 9342    12
# 9345    12
# 9352    12
# 9392    12
# Name: date_out_month, Length: 539, dtype: int32

# %%
# List of columns to visualize
date_columns = ['date_in_year', 'date_out_year']

# Create a figure with subplots
fig, axes = plt.subplots(nrows=1, ncols=len(date_columns), figsize=(16, 6))

# Loop through date_columns and plot countplots
for i, column in enumerate(date_columns):
    sns.countplot(x=df_copy[column], ax=axes[i], color='skyblue')
    axes[i].set_title(f'Number of {column} by year')
    axes[i].set_xlabel('Year')
    axes[i].set_ylabel('Count')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### label encoding untuk data ordinal

# %%
# Label encode (mapping) age_group
age_mapping = {'0-18': 0, '19-30': 1, '31-45': 2, '46-60': 3, '60+': 4}
df['age_group'] = df['age_group'].replace(age_mapping).astype(int)

# Label encode (mapping) review
review_mapping = {'Sangat Tidak Puas': 0, 'Tidak Puas': 1, 'Netral': 2, 'Puas': 3, 'Sangat Puas': 4}
df['review_encoded'] = df['review'].replace(review_mapping).astype(int)

# Label encode (mapping) room_type
room_mapping = {'Tidak Digunakan': 0, 'Kelas 3': 1, 'Kelas 2': 2, 'Kelas 1': 3, 'VIP': 4}
df['room_type_encoded'] = df['room_type'].replace(room_mapping).astype(int)

# %% [markdown]
# ### One-hot encoding (data non-ordinal)

# %%
# One-Hot Encoding
onehot_cols = ['branch', 'hospital_care', 'payment', 'gender', 'drug_brand', 'drug_type', 'doctor', 'lab']

for col in onehot_cols:
    onehots = pd.get_dummies(df[col], prefix=col, dtype=int)  # Specify dtype=int to convert to integers
    df = df.join(onehots)
    df = df.drop(col, axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 539 entries, 9 to 9392
# Data columns (total 68 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            539 non-null    int64
#  1   date_in                       539 non-null    datetime64[ns]
#  2   date_out                      539 non-null    datetime64[ns]
#  3   drug_quantity                 539 non-null    int64
#  4   admin_price                   539 non-null    int64
#  5   cogs                          539 non-null    int64
#  6   review                        539 non-null    object
#  7   patient_id                    539 non-null    int64
#  8   room_id                       539 non-null    int64
#  9   drug_id                       539 non-null    int64
#  10  doctor_id                     539 non-null    int64
#  11  surgery_id                    539 non-null    int64
#  12  lab_id                        539 non-null    int64
#  13  patient_name                  539 non-null    object
#  14  age                           539 non-null    int64
#  15  room_type                     539 non-null    object
#  16  food_price                    539 non-null    float64
#  17  room_price                    539 non-null    float64
#  18  drug_price                    539 non-null    int64
#  19  doctor_price                  539 non-null    int64
#  20  surgery                       539 non-null    object
#  21  surgery_price                 539 non-null    float64
#  22  lab_price                     539 non-null    float64
#  23  drug_price_total              539 non-null    int64
#  24  days_diff                     539 non-null    float64
#  25  doctor_visit_price            539 non-null    float64
#  26  room_price_total              539 non-null    int64
#  27  food_price_total              539 non-null    float64
#  28  surgery_price_total           539 non-null    int64
#  29  lab_price_total               539 non-null    int64
#  30  infus_price_total             539 non-null    float64
#  31  total_amount                  539 non-null    int64
#  32  revenue                       539 non-null    int64
#  33  created_at                    539 non-null    datetime64[ns]
#  34  is_DBD                        539 non-null    bool
#  35  age_group                     539 non-null    int32
#  36  date_in_year                  539 non-null    int32
#  37  date_in_month                 539 non-null    int32
#  38  date_out_year                 539 non-null    int32
#  39  date_out_month                539 non-null    int32
#  40  review_encoded                539 non-null    int32
#  41  room_type_encoded             539 non-null    int32
#  42  branch_RSMA                   539 non-null    int32
#  43  branch_RSMD                   539 non-null    int32
#  44  branch_RSMS                   539 non-null    int32
#  45  hospital_care_Rawat Inap      539 non-null    int32
#  46  hospital_care_Rawat Jalan     539 non-null    int32
#  47  payment_Asuransi              539 non-null    int32
#  48  payment_Pribadi               539 non-null    int32
#  49  gender_Laki-laki              539 non-null    int32
#  50  gender_Perempuan              539 non-null    int32
#  51  drug_brand_Blackmores         539 non-null    int32
#  52  drug_brand_Calpol             539 non-null    int32
#  53  drug_brand_Diclofenac         539 non-null    int32
#  54  drug_brand_Enervon-C          539 non-null    int32
#  55  drug_brand_Holland & Barrett  539 non-null    int32
#  56  drug_brand_Naproxen           539 non-null    int32
#  57  drug_brand_Panadol            539 non-null    int32
#  58  drug_brand_Paramex            539 non-null    int32
#  59  drug_brand_Tramadol           539 non-null    int32
#  60  drug_type_Pereda Nyeri        539 non-null    int32
#  61  drug_type_Umum                539 non-null    int32
#  62  drug_type_Vitamin             539 non-null    int32
#  63  doctor_Penyakit Dalam         539 non-null    int32
#  64  doctor_Umum                   539 non-null    int32
#  65  lab_Hematologi                539 non-null    int32
#  66  lab_Kimia Darah               539 non-null    int32
#  67  lab_Serologi                  539 non-null    int32
# dtypes: bool(1), datetime64[ns](3), float64(8), int32(33), int64(19), object(4)
# memory usage: 233.6+ KB

# %%
correlation = df[['age', 'age_group', 'date_in_year', 'date_in_month', 'date_out_year', 'date_out_month']].corrwith(df['total_amount'])
correlation_sorted = correlation.sort_index()

print(correlation_sorted)
# Out:
# age              -0.047720
# age_group        -0.052541
# date_in_month    -0.022759
# date_in_year      0.006623
# date_out_month   -0.023670
# date_out_year     0.010833
# dtype: float64

# %%
column_to_drop = column_to_drop + ['date_in', 'date_out', 'age', 
                                   'hospital_care_Rawat Jalan', 'gender_Perempuan', 'payment_Pribadi',
                                   'review', 'room_type', 'surgery',
                                   'date_in_month', 'date_in_year', 'date_out_year', 'date_out_month',
                                   'review_encoded'
                                  ]

# %%
# Set display options to show all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# calculate correlation and print correlation_sorted
correlation = df.select_dtypes(include=[np.number]).corrwith(df['total_amount'])
#correlation_sorted = correlation.sort_index()
correlation_sorted = correlation.abs().sort_values(ascending=False)

print(correlation_sorted)

# Reset display options to default after printing
pd.reset_option('display.max_rows')
pd.reset_option('display.max_columns')
# Out:
# total_amount                    1.000000
# room_price_total                0.981422
# days_diff                       0.976603
# infus_price_total               0.976603
# doctor_visit_price              0.967646
# food_price_total                0.943792
# hospital_care_Rawat Inap        0.861361
# hospital_care_Rawat Jalan       0.861361
# room_price                      0.859377
# revenue                         0.830170
# food_price                      0.822647
# room_type_encoded               0.798541
# room_id                         0.749924
# payment_Asuransi                0.489552
# payment_Pribadi                 0.489552
# drug_price_total                0.133685
# drug_type_Vitamin               0.123274
# drug_price                      0.120820
# branch_RSMS                     0.098553
# drug_brand_Blackmores           0.096891
# drug_quantity                   0.081387
# gender_Laki-laki                0.079521
# gender_Perempuan                0.079521
# drug_brand_Diclofenac           0.076632
# drug_brand_Panadol              0.073394
# drug_brand_Enervon-C            0.067110
# drug_type_Pereda Nyeri          0.066211
# age_group                       0.052541
# drug_type_Umum                  0.052408
# branch_RSMD                     0.050745
# cogs                            0.049969
# age                             0.047720
# branch_RSMA                     0.047676
# lab_id                          0.031107
# lab_Kimia Darah                 0.030132
# drug_brand_Naproxen             0.028811
# doctor_id                       0.027722
# doctor_Penyakit Dalam           0.027722
# doctor_Umum                     0.027722
# doctor_price                    0.027722
# drug_brand_Holland & Barrett    0.026315
# review_encoded                  0.024247
# date_out_month                  0.023670
# date_in_month                   0.022759
# lab_Hematologi                  0.021157
# lab_price                       0.020200
# lab_price_total                 0.020200
# id                              0.015900
# drug_id                         0.011036
# date_out_year                   0.010833
# lab_Serologi                    0.008998
# drug_brand_Calpol               0.008249
# date_in_year                    0.006623
# drug_brand_Paramex              0.003878
# drug_brand_Tramadol             0.003173
# patient_id                      0.003138
# admin_price                          NaN
# surgery_id                           NaN
# surgery_price                        NaN
# surgery_price_total                  NaN
# dtype: float64

# %%
column_to_drop = column_to_drop + ['doctor_price', 'drug_price', 'food_price', 'lab_price', 'room_price', 'surgery_price']

# %% [markdown]
# ## Feature Selection

# %%
final_df = df.drop(column_to_drop, axis=1)
final_df.head()
# Out:
#      drug_quantity  days_diff  total_amount  age_group  room_type_encoded  \
# 9                3        0.0        590000          2                  0
# 51               1        0.0        550000          2                  0
# 71               5        3.0       2825000          4                  3
# 150              3        0.0        700000          4                  0
# 161              3        0.0        560000          3                  0
#
#      branch_RSMA  branch_RSMD  branch_RSMS  hospital_care_Rawat Inap  \
# 9              0            1            0                         0
# 51             0            1            0                         0
# 71             0            0            1                         1
# 150            0            0            1                         0
# 161            0            1            0                         0
#
#      payment_Asuransi  ...  drug_brand_Paramex  drug_brand_Tramadol  \
# 9                   0  ...                   0                    0
# 51                  0  ...                   0                    0
# 71                  1  ...                   0                    0
# 150                 0  ...                   0                    0
# 161                 0  ...                   0                    0
#
#      drug_type_Pereda Nyeri  drug_type_Umum  drug_type_Vitamin  \
# 9                         1               0                  0
# 51                        1               0                  0
# 71                        1               0                  0
# 150                       1               0                  0
# 161                       0               1                  0
#
#      doctor_Penyakit Dalam  doctor_Umum  lab_Hematologi  lab_Kimia Darah  \
# 9                        1            0               1                0
# 51                       0            1               0                0
# 71                       0            1               0                0
# 150                      1            0               0                0
# 161                      1            0               1                0
#
#      lab_Serologi
# 9               0
# 51              1
# 71              1
# 150             1
# 161             0
#
# [5 rows x 28 columns]

# %%
# Set display options to show all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# calculate correlation and print correlation_sorted
correlation = final_df.corrwith(df['total_amount'])
#correlation_sorted = correlation.sort_index()
correlation_sorted = correlation.abs().sort_values(ascending=False)

print(correlation_sorted)

# Reset display options to default after printing
pd.reset_option('display.max_rows')
pd.reset_option('display.max_columns')
# Out:
# total_amount                    1.000000
# days_diff                       0.976603
# hospital_care_Rawat Inap        0.861361
# room_type_encoded               0.798541
# payment_Asuransi                0.489552
# drug_type_Vitamin               0.123274
# branch_RSMS                     0.098553
# drug_brand_Blackmores           0.096891
# drug_quantity                   0.081387
# gender_Laki-laki                0.079521
# drug_brand_Diclofenac           0.076632
# drug_brand_Panadol              0.073394
# drug_brand_Enervon-C            0.067110
# drug_type_Pereda Nyeri          0.066211
# age_group                       0.052541
# drug_type_Umum                  0.052408
# branch_RSMD                     0.050745
# branch_RSMA                     0.047676
# lab_Kimia Darah                 0.030132
# drug_brand_Naproxen             0.028811
# doctor_Penyakit Dalam           0.027722
# doctor_Umum                     0.027722
# drug_brand_Holland & Barrett    0.026315
# lab_Hematologi                  0.021157
# lab_Serologi                    0.008998
# drug_brand_Calpol               0.008249
# drug_brand_Paramex              0.003878
# drug_brand_Tramadol             0.003173
# dtype: float64

# %%
# Separate features and target
X = final_df.drop('total_amount', axis=1)
y = final_df['total_amount']

# %%
# Initialize the MinMaxScaler
mms = MinMaxScaler()
X_mms = mms.fit_transform(X)

# %% [markdown]
# ## Machine Learning Modeling and Evaluation

# %%
# splitting data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_mms, y, test_size=0.2, random_state=42)

# %%
X_train.shape, X_test.shape
# Out:
# ((431, 27), (108, 27))

# %%
import time
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
from sklearn.model_selection import cross_val_score

# regression models
models = {
    'Linear Regression': LinearRegression(),
    'Decision Tree': DecisionTreeRegressor(random_state=42),
    'KNN': KNeighborsRegressor(),
    'SVR': SVR(),
    'Random Forest': RandomForestRegressor(random_state=42),
    'XGBoost': XGBRegressor(random_state=42),
}

# Loop through the models
for name, model in models.items():
    # Perform cross-validation
    cv_scores_r2 = cross_val_score(model, X_train, y_train, cv=5, scoring='r2')

    # Train the model on the entire training set
    model.fit(X_train, y_train)

    # Predictions on the training set
    y_pred_train = model.predict(X_train)

    # Predictions on the test set
    start_time = time.time()
    y_pred_test = model.predict(X_test)
    end_time = time.time()
    prediction_time = end_time - start_time

    # Calculate evaluation metrics for training and test sets
    mse_train = mean_squared_error(y_train, y_pred_train)
    mse_test = mean_squared_error(y_test, y_pred_test)
    mae_train = mean_absolute_error(y_train, y_pred_train)
    mae_test = mean_absolute_error(y_test, y_pred_test)
    mape_train = mean_absolute_percentage_error(y_train, y_pred_train)
    mape_test = mean_absolute_percentage_error(y_test, y_pred_test)
    r2_train = r2_score(y_train, y_pred_train)
    r2_test = r2_score(y_test, y_pred_test)

    print(f'--------{name} Regression------')
    print("Cross-Validation R²: %.5f (+/- %.5f)" % (cv_scores_r2.mean(), cv_scores_r2.std() * 2))
    print("Training R²: %.5f" % r2_train)
    print("Test R²: %.5f" % r2_test)
    print("Training MSE: %.5f" % mse_train)
    print("Test MSE: %.5f" % mse_test)
    print("Training MAE: %.5f" % mae_train)
    print("Test MAE: %.5f" % mae_test)
    print("Training RMSE: %.5f" % np.sqrt(mse_train))
    print("Test RMSE: %.5f" % np.sqrt(mse_test))
    print("Training MAPE: %.5f" % (mape_train * 100) + '%')
    print("Test MAPE: %.5f" % (mape_test * 100) + '%')
    print(f'Time taken for prediction on test set: {prediction_time:.10f} seconds')
    print('\n')
# Out:
# --------Linear Regression Regression------
# Cross-Validation R²: 0.99434 (+/- 0.00294)
# Training R²: 0.99518
# Test R²: 0.99578
# Training MSE: 12237119100.96192
# Test MSE: 12089829811.13236
# Training MAE: 83477.83807
# Test MAE: 79958.81328
# Training RMSE: 110621.51283
# Test RMSE: 109953.76215
# Training MAPE: 5.57739%
# Test MAPE: 4.81467%
# Time taken for prediction on test set: 0.0000000000 seconds
#
#
# --------Decision Tree Regression------
# Cross-Validation R²: 0.98815 (+/- 0.00619)
# Training R²: 1.00000
# Test R²: 0.99133
# Training MSE: 0.00000
# Test MSE: 24836805555.55556
# Training MAE: 0.00000
# Test MAE: 92731.48148
# Training RMSE: 0.00000
# Test RMSE: 157596.97191
# Training MAPE: 0.00000%
# Test MAPE: 3.37666%
# Time taken for prediction on test set: 0.0000000000 seconds
#
#
# --------KNN Regression------
# Cross-Validation R²: 0.69575 (+/- 0.03535)
# Training R²: 0.81570
# Test R²: 0.72606
# Training MSE: 467740603248.25989
# Test MSE: 784699925925.92590
# Training MAE: 475512.76102
# Test MAE: 551851.85185
# Training RMSE: 683915.64045
# Test RMSE: 885832.89955
# Training MAPE: 24.07202%
# Test MAPE: 22.10503%
# Time taken for prediction on test set: 0.0312504768 seconds
#
#
# --------SVR Regression------
# Cross-Validation R²: -0.06201 (+/- 0.14994)
# Training R²: -0.03417
# Test R²: -0.11817
# Training MSE: 2624624097547.16016
# Test MSE: 3203017045014.53418
# Training MAE: 1403116.59965
# Test MAE: 1565263.02300
# Training RMSE: 1620069.16443
# Test RMSE: 1789697.47304
# Training MAPE: 107.77958%
# Test MAPE: 104.07939%
# Time taken for prediction on test set: 0.0156316757 seconds
#
#
# --------Random Forest Regression------
# Cross-Validation R²: 0.99294 (+/- 0.00414)
# Training R²: 0.99921
# Test R²: 0.99627
# Training MSE: 1993289559.16473
# Test MSE: 10683982361.11111
# Training MAE: 25899.30394
# Test MAE: 64321.29630
# Training RMSE: 44646.27150
# Test RMSE: 103363.35115
# Training MAPE: 0.99502%
# Test MAPE: 2.46207%
# Time taken for prediction on test set: 0.0187230110 seconds
#
#
# --------XGBoost Regression------
# Cross-Validation R²: 0.99732 (+/- 0.00154)
# Training R²: 1.00000
# Test R²: 0.99787
# Training MSE: 45496.85382
# Test MSE: 6102962261.32001
# Training MAE: 142.43808
# Test MAE: 43720.05642
# Training RMSE: 213.29992
# Test RMSE: 78121.45839
# Training MAPE: 0.01560%
# Test MAPE: 1.42083%
# Time taken for prediction on test set: 0.0000000000 seconds

# %% [markdown]
# ## Hyperparameter Tuning Random Search

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
models_tuning = {
    'XGBoost': (XGBRegressor(random_state=42), {
        'max_depth': [3, 6, 9, 12],
        'learning_rate': [0.01, 0.1, 0.2, 0.3],
        'n_estimators': [100, 200, 300, 400],
        'subsample': [0.6, 0.7, 0.8, 0.9, 1.0],
        'colsample_bytree': [0.6, 0.7, 0.8, 0.9, 1.0]
    })
}

# Loop through the models
for name, (model, param_grid) in models_tuning.items():
    # Create a randomized search for the model
    random_search = RandomizedSearchCV(model, param_grid, cv=5, scoring='neg_mean_squared_error')
    random_search.fit(X_train, y_train)

    # Get the best hyperparameters and model
    best_params = random_search.best_params_
    best_model = random_search.best_estimator_

    # Train the best model on the entire training set
    best_model.fit(X_train, y_train)

    # Predictions on the training set
    y_pred_train = best_model.predict(X_train)

    # Predictions on the test set
    start_time = time.time()
    y_pred_test = best_model.predict(X_test)
    end_time = time.time()
    prediction_time = end_time - start_time

    # Calculate evaluation metrics for training and test sets
    mse_train = mean_squared_error(y_train, y_pred_train)
    mse_test = mean_squared_error(y_test, y_pred_test)
    mae_train = mean_absolute_error(y_train, y_pred_train)
    mae_test = mean_absolute_error(y_test, y_pred_test)
    mape_train = mean_absolute_percentage_error(y_train, y_pred_train)
    mape_test = mean_absolute_percentage_error(y_test, y_pred_test)
    r2_train = r2_score(y_train, y_pred_train)
    r2_test = r2_score(y_test, y_pred_test)

    print(f'--------{name} Regression (Tuned)------')
    print("Cross-Validation R²: %.5f (+/- %.5f)" % (cv_scores_r2.mean(), cv_scores_r2.std() * 2))
    print("Training R²: %.5f" % r2_train)
    print("Test R²: %.5f" % r2_test)
    print("Training MSE: %.5f" % mse_train)
    print("Test MSE: %.5f" % mse_test)
    print("Training MAE: %.5f" % mae_train)
    print("Test MAE: %.5f" % mae_test)
    print("Training RMSE: %.5f" % np.sqrt(mse_train))
    print("Test RMSE: %.5f" % np.sqrt(mse_test))
    print("Training MAPE: %.5f" % (mape_train * 100) + '%')
    print("Test MAPE: %.5f" % (mape_test * 100) + '%')
    print(f'Time taken for prediction on test set: {prediction_time:.10f} seconds')
    print('\n')
# Out:
# --------XGBoost Regression (Tuned)------
# Cross-Validation R²: 0.99732 (+/- 0.00154)
# Training R²: 0.99994
# Test R²: 0.99933
# Training MSE: 148423314.15405
# Test MSE: 1926154664.62879
# Training MAE: 8966.73079
# Test MAE: 27319.43258
# Training RMSE: 12182.91074
# Test RMSE: 43887.97859
# Training MAPE: 0.56867%
# Test MAPE: 1.14425%
# Time taken for prediction on test set: 0.0000000000 seconds

# %% [markdown]
# ## Model Comparison

# %%
import pandas as pd

data = {
    "Model": ["XGBoost Regression", "XGBoost Regression (Tuned)"],
    "Cross-Validation R²": [0.99732, 0.99732],
    "Train R²": [1.00000, 0.99994],
    "Test R²": [0.99787, 0.99933],
    "Train MSE": [45496.85382, 148423314.15405],
    "Test MSE": [6102962261.32001, 1926154664.62879],
    "Train MAE": [142.43808, 8966.73079],
    "Test MAE": [43720.05642, 27319.43258],
    "Train RMSE": [213.29992, 12182.91074],
    "Test RMSE": [78121.45839, 43887.97859],
    "Train MAPE": ["0.01560%", "0.56867%"],
    "Test MAPE": ["1.42083%", "1.14425%"],
    "Waktu prediksi (s)": ["0.0000000000", "0.0000000000"]
}

comparison = pd.DataFrame(data)
comparison
# Out:
#                         Model  Cross-Validation R²  Train R²  Test R²  \
# 0          XGBoost Regression              0.99732   1.00000  0.99787
# 1  XGBoost Regression (Tuned)              0.99732   0.99994  0.99933
#
#       Train MSE      Test MSE   Train MAE     Test MAE   Train RMSE  \
# 0  4.549685e+04  6.102962e+09   142.43808  43720.05642    213.29992
# 1  1.484233e+08  1.926155e+09  8966.73079  27319.43258  12182.91074
#
#      Test RMSE Train MAPE Test MAPE Waktu prediksi (s)
# 0  78121.45839   0.01560%  1.42083%       0.0000000000
# 1  43887.97859   0.56867%  1.14425%       0.0000000000
